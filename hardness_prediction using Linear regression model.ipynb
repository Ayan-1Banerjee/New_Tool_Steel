# %%
import numpy as np
import pandas as pd 
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns 
import smogn 
import gym
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px
import plotly.io as pio
import metallurgy
pio.renderers.default = "plotly_mimetype+notebook"

# %%
data1=pd.read_csv(r"C:\Users\Ayan\Desktop\My Project\carbonsteel.csv", sep=',', encoding='unicode_escape') ## encoding='unicode_escape'
data1.shape
# Out:
# (190, 27)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SAE Grade       190 non-null    object
#  1   Conditions      190 non-null    object
#  2   UTS (MPa)       190 non-null    int64
#  3   UTS (Ksi)       190 non-null    int64
#  4   YS (MPa)        190 non-null    int64
#  5   YS (ksi)        190 non-null    object
#  6   Elongation (%)  190 non-null    float64
#  7   Reduction (%)   190 non-null    object
#  8   Hardness (HB)   190 non-null    object
#  9   C (Min)         178 non-null    float64
#  10  C (Max)         190 non-null    float64
#  11  Mn (Min)        190 non-null    float64
#  12  Mn (Max)        190 non-null    float64
#  13  P (Min)         3 non-null      object
#  14  P (Max)         190 non-null    float64
#  15  S (Min)         28 non-null     float64
#  16  S(Max)          190 non-null    float64
# ...

# %%
data1.head()
# Out:
#   SAE Grade  Conditions  UTS (MPa)  UTS (Ksi)  YS (MPa) YS (ksi)  \
# 0      1006  Hot rolled        295         43       165       24
# 1      1006  Cold drawn        330         48       285       41
# 2      1008  Hot rolled        305         44       170     24.5
# 3      1008  Cold drawn        340         49       285       42
# 4      1010  Hot rolled        325         47       180       26
#
#    Elongation (%) Reduction (%) Hardness (HB)  C (Min)  ...  Si (Min)  \
# 0            30.0            55            86      NaN  ...       NaN
# 1            20.0            45            95      NaN  ...       NaN
# 2            30.0            55            86      NaN  ...       NaN
# 3            20.0            45            95      NaN  ...       NaN
# 4            28.0            50            95     0.08  ...       NaN
#
#    Si (Max)  Ni (Min) Ni (Max)  Cr (Min)  Cr (Max)  Mo (Min)  Mo (Max)  \
# 0       NaN       NaN      NaN       NaN       NaN       NaN       NaN
# ...

# %%
data0= pd.read_excel(r"C:\Users\Ayan\Desktop\My Project\QP_steel_Rawdata.xlsx")
data0.shape
# Out:
# (361, 14)

# %%
data0.head()
# Out:
#    DataSourceRef     C    Si    Mn  TMAE     Ac1         Ac3     MS  Qtemp  \
# 0            105  0.40  1.70  2.00   0.0  747.22  819.113733  252.0    200
# 1             92  0.19  1.87  1.49   0.0  758.57  877.692719  160.0    140
# 2             92  0.19  1.87  1.49   0.0  758.57  877.692719  160.0    140
# 3            105  0.40  1.80  2.00   0.0  749.04  822.513733  247.0    190
# 4            105  0.40  1.80  2.00   0.0  749.04  822.513733  247.0    190
#
#    Ptemp MicrostructureType 1 MicrostructureType 2 MicrostructureType 3  \
# 0    360                    M                    B                   RA
# 1    400                    M                   RA                  NaN
# 2    400                    M                    B                   RA
# 3    360                    M                    B                   RA
# 4    360                    M                    B                   RA
#
#   MicrostructureType 4
# 0                  NaN
# 1                  NaN
# ...

# %%
data1=pd.read_csv(r"C:\Users\Ayan\Desktop\My Project\Stainless Steel.csv", sep=',', encoding='unicode_escape') ## encoding='unicode_escape'
data1.shape
# Out:
# (65, 28)

# %%
data1.head(50)
# Out:
#                           SAE Grade  \
# 0      Ferritic stainless steels(b)
# 1                               405
# 2                               405
# 3                               409
# 4                               430
# 5                               442
# 6                               442
# 7                               446
# 8                               446
# 9   Martensitic stainless steels(b)
# 10                              403
# 11                              403
# 12                              410
# 13                              410
# 14                              414
# 15                              414
# 16                              414
# 17                              420
# 18                              420
# 19                              431
# 20                              431
# 21                              431
# 22                              431
# 23                             440C
# 24                             440C
# ...

# %%
data2 = data1.fillna(0)
data2
# Out:
#                        SAE Grade                       Conditions  UTS (MPa)  \
# 0   Ferritic stainless steels(b)                                0        0.0
# 1                            405                     Annealed bar      483.0
# 2                            405                   Cold drawn bar      586.0
# 3                            409                     Annealed bar      450.0
# 4                            430                     Annealed bar      517.0
# ..                           ...                              ...        ...
# 60                           330                     Annealed bar      585.0
# 61                           384  Annealed wire 1040 °C (1900 °F)      515.0
# 62                             0                                0        0.0
# 63                             0                                0        0.0
# 64                             0                                0        0.0
#
# ...

# %%
data3=pd.read_csv(r"C:\Users\Ayan\Desktop\My Project\carbonsteel.csv", sep=',', encoding='unicode_escape') ## encoding='unicode_escape'
data3.shape
# Out:
# (190, 27)

# %%
data4 = data3.fillna(0)
data4
# Out:
#     SAE Grade                                         Conditions  UTS (MPa)  \
# 0        1006                                         Hot rolled        295
# 1        1006                                         Cold drawn        330
# 2        1008                                         Hot rolled        305
# 3        1008                                         Cold drawn        340
# 4        1010                                         Hot rolled        325
# ..        ...                                                ...        ...
# 185      9255                     Normalized at 900 °C (1650 °F)        931
# 186      9255                       Annealed at 845 °C (1550 °F)        779
# 187      9255  Oi I quenched from 885 °C (1625 °F) and temper...       1130
# 188      9310                     Normalized at 890 °C (1630 °F)        910
# 189      9310                       Annealed at 845 °C (1550 °F)        820
#
# ...

# %%
data5=pd.read_csv(r"C:\Users\Ayan\Desktop\My Project\database_classification.csv", sep=',', encoding='unicode_escape') ## encoding='unicode_escape'
data5.shape
# Out:
# (652, 25)

# %%
data6 = data5.fillna(0)
data6
# Out:
#          Name Class      Fe     Cr     Ni   Mo   Mn      C    Ti     Si  ...  \
# 0          10     P  98.320   0.15   0.25  0.0  0.5  0.105  0.00  0.270  ...
# 1          10     P  98.320   0.15   0.25  0.0  0.5  0.105  0.00  0.270  ...
# 2         15K     P  98.055   0.30   0.30  0.0  0.5  0.160  0.00  0.225  ...
# 3          20     P  98.115   0.25   0.25  0.0  0.5  0.205  0.00  0.270  ...
# 4          20     P  98.115   0.25   0.25  0.0  0.5  0.205  0.00  0.270  ...
# ..        ...   ...     ...    ...    ...  ...  ...    ...   ...    ...  ...
# 647   XN35VTU  FeNi  42.175  15.00  35.00  0.0  0.3  0.040  2.80  0.300  ...
# 648   XN35VTU  FeNi  42.175  15.00  35.00  0.0  0.3  0.040  2.80  0.300  ...
# 649   XN35VTU  FeNi  42.175  15.00  35.00  0.0  0.3  0.040  2.80  0.300  ...
# 650   XN35VTU  FeNi  42.175  15.00  35.00  0.0  0.3  0.040  2.80  0.300  ...
# 651  36NXTU8M  FeNi  37.605  12.75  36.00  8.0  1.0  0.025  2.95  0.500  ...
#
# ...

# %%
element = ['Nb', 'Mo', 'Zr','Cr','Mn','V',
            'Hf', 'Ta', 'W', 'C', 'Mg', 'Zn', 
            'Si', 'N', 'B', 'Sc', 'Y', 'Pd', 'Ag',
            'Re', 'Li', 'Ca', 'Ga', 'Sn']

# %%
data5['Fe']
# Out:
# 0      98.320
# 1      98.320
# 2      98.055
# 3      98.115
# 4      98.115
#         ...
# 647    42.175
# 648    42.175
# 649    42.175
# 650    42.175
# 651    37.605
# Name: Fe, Length: 652, dtype: float64

# %%
data2['C (Max)']
# Out:
# 0     0.00
# 1     0.08
# 2     0.08
# 3     0.08
# 4     0.12
#       ...
# 60    0.08
# 61    0.08
# 62    0.00
# 63    0.00
# 64    0.00
# Name: C (Max), Length: 65, dtype: float64

# %%
ss=pd.read_csv(r"C:\Users\Ayan\Desktop\My Project\steel_strength(now).csv", sep=',', encoding='unicode_escape') ## encoding='unicode_escape'
ss.shape
# Out:
# (312, 17)

# %%
ss['fe'] = 100 - ss[['c', 'mn', 'si', 'cr', 'ni', 'mo', 'v', 'n', 'nb', 'co', 'w', 'al', 'ti']].sum(axis=1)
print(ss)
# Out:
#                                                formula     c    mn    si  \
# 0    Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  0.02  0.05  0.05
# 1    Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  0.18  0.01  0.01
# 2    Fe0.625Mn0.000102Si0.000200Cr0.0936Ni0.129Mo0....  0.00  0.01  0.01
# 3    Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  0.01  0.05  0.05
# 4    Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  0.01  0.05  0.05
# ..                                                 ...   ...   ...   ...
# 307  Fe0.823C0.0176Mn0.00183Si0.000198Cr0.0779Ni0.0...  0.38  0.18  0.01
# 308  Fe0.823Mn0.000618Si0.00101Cr0.0561Ni0.0984Mo0....  0.00  0.06  0.05
# 309  Fe0.825C0.0174Mn0.00175Si0.000201Cr0.0565Ni0.0...  0.37  0.17  0.01
# 310  Fe0.858C0.0191Mn0.00194Si0.000199Cr0.0753Ni0.0...  0.41  0.19  0.01
# 311  Fe0.860C0.0125Mn0.00274Si0.000198Cr0.00439Ni0....  0.27  0.27  0.01
#
#         cr     ni    mo     v     n    nb     co     w    al    ti  \
# ...

# %%
ssn = ss.drop(['tensile strength', 'elongation'], axis=1)

# %%
col = ss.pop('fe')
ss.insert(1,col.name,col)

# %%
ss.head()
# Out:
#                                              formula     fe     c    mn    si  \
# 0  Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  60.50  0.02  0.05  0.05
# 1  Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  60.98  0.18  0.01  0.01
# 2  Fe0.625Mn0.000102Si0.000200Cr0.0936Ni0.129Mo0....  62.16  0.00  0.01  0.01
# 3  Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  61.61  0.01  0.05  0.05
# 4  Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  62.43  0.01  0.05  0.05
#
#       cr     ni    mo     v     n    nb     co     w    al    ti  \
# 0   0.01  19.70  2.95  0.01  0.00  0.01  15.00  0.00  0.15  1.55
# 1  13.44   0.01  3.01  0.46  0.04  0.01  19.46  2.35  0.04  0.00
# 2   8.67  13.45  0.82  0.01  0.00  0.01  13.90  0.00  0.39  0.57
# 3   0.01  17.70  3.95  0.01  0.00  0.01  15.00  0.00  0.13  1.47
# 4   0.01  19.40  1.45  0.01  0.00  0.01  14.90  0.00  0.13  1.55
#
#    yield strength  tensile strength  elongation
# 0          2411.5            2473.5         7.0
# ...

# %%
ss = ss.fillna(0)
ss.head(313)
# Out:
#                                                formula     fe     c    mn  \
# 0    Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  60.50  0.02  0.05
# 1    Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  60.98  0.18  0.01
# 2    Fe0.625Mn0.000102Si0.000200Cr0.0936Ni0.129Mo0....  62.16  0.00  0.01
# 3    Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  61.61  0.01  0.05
# 4    Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  62.43  0.01  0.05
# ..                                                 ...    ...   ...   ...
# 307  Fe0.823C0.0176Mn0.00183Si0.000198Cr0.0779Ni0.0...  82.48  0.38  0.18
# 308  Fe0.823Mn0.000618Si0.00101Cr0.0561Ni0.0984Mo0....  81.19  0.00  0.06
# 309  Fe0.825C0.0174Mn0.00175Si0.000201Cr0.0565Ni0.0...  81.53  0.37  0.17
# 310  Fe0.858C0.0191Mn0.00194Si0.000199Cr0.0753Ni0.0...  85.57  0.41  0.19
# 311  Fe0.860C0.0125Mn0.00274Si0.000198Cr0.00439Ni0....  86.26  0.27  0.27
#
#        si     cr     ni    mo     v     n    nb     co     w    al    ti  \
# ...

# %% [markdown]
# ## Mapping of multiple features

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   formula           312 non-null    object
#  1   fe                312 non-null    float64
#  2   c                 312 non-null    float64
#  3   mn                312 non-null    float64
#  4   si                312 non-null    float64
#  5   cr                312 non-null    float64
#  6   ni                312 non-null    float64
#  7   mo                312 non-null    float64
#  8   v                 312 non-null    float64
#  9   n                 312 non-null    float64
#  10  nb                312 non-null    float64
#  11  co                312 non-null    float64
#  12  w                 312 non-null    float64
#  13  al                312 non-null    float64
#  14  ti                312 non-null    float64
#  15  yield strength    312 non-null    float64
# ...

# %%
ss.describe().transpose()
# Out:
#                   count         mean         std      min        25%  \
# fe                312.0    72.597324    5.283250    60.50    68.5075
# c                 312.0     0.096442    0.109008     0.00     0.0100
# mn                312.0     0.146250    0.397102     0.01     0.0100
# si                312.0     0.221218    0.580796     0.01     0.0100
# cr                312.0     8.043830    5.426169     0.01     3.1000
# ni                312.0     8.184006    6.337055     0.01     0.9600
# mo                312.0     2.766090    1.832908     0.02     1.5000
# v                 312.0     0.183750    0.452462     0.00     0.0100
# n                 312.0     0.005545    0.018331     0.00     0.0000
# nb                312.0     0.035449    0.161537     0.00     0.0100
# co                312.0     7.008782    6.254431     0.01     0.0100
# w                 312.0     0.161282    0.920211     0.00     0.0000
# al                312.0     0.239135    0.340110     0.01     0.0300
# ...

# %%
ss.columns
# Out:
# Index(['formula', 'fe', 'c', 'mn', 'si', 'cr', 'ni', 'mo', 'v', 'n', 'nb',
#        'co', 'w', 'al', 'ti', 'yield strength', 'tensile strength',
#        'elongation'],
#       dtype='object')

# %%
ssd=ssn.drop(['formula'], axis=1)
sns.pairplot(ssd)
plt.savefig('pairplot.png')

# %%
ss1 = ss[['c', 'mn', 'si', 'yield strength']]
sns.pairplot(ss1, hue='yield strength')
plt.savefig('c_mn_si.png')

# %%
ss1 = ss[['cr', 'ni', 'mo', 'yield strength']]
sns.pairplot(ss1, hue='yield strength')
plt.savefig('cr_ni_mo.png')

# %%
ss1 = ss[['v', 'n', 'nb','yield strength']]
sns.pairplot(ss1, hue='yield strength')
plt.savefig('v_n_nb.png')

# %%
ss1 = ss[['co', 'w','al', 'ti','fe', 'yield strength']]
sns.pairplot(ss1, hue='yield strength')
plt.savefig('co_w_al_ti_fe.png')

# %%
ss1 = ss[['c', 'mn', 'si','tensile strength']]
sns.pairplot(ss1, hue='tensile strength')

# %%
ss1 = ss[['cr', 'ni', 'mo','tensile strength']]
sns.pairplot(ss1, hue='tensile strength')

# %%
ss1 = ss[['v', 'n', 'nb','tensile strength']]
sns.pairplot(ss1, hue='tensile strength')

# %%
ss1 = ss[['co', 'w','al', 'ti','fe','tensile strength']]
sns.pairplot(ss1, hue='tensile strength')

# %%
ss1 = ss[['c', 'mn', 'si','elongation']]
sns.pairplot(ss1, hue='elongation')

# %%
ss1 = ss[['cr', 'ni', 'mo','elongation']]
sns.pairplot(ss1, hue='elongation')

# %%
ss1 = ss[['v', 'n', 'nb','elongation']]
sns.pairplot(ss1, hue='elongation')

# %%
ss1 = ss[['co', 'w','al', 'ti','fe','elongation']]
sns.pairplot(ss1, hue='elongation')

# %%
plt.figure(figsize=(12,6))
sns.heatmap(ssd.corr(), annot=True)
plt.savefig('heatmap.png')

# %%
class_distribution = ssd['yield strength'].value_counts()

print('Class Distribution:')
print(class_distribution)

# %% [markdown]
# ## Creating features and y labels
# ## For 1. Yield Strength

# %%
X = ssd.drop(['yield strength','tensile strength','elongation'],axis=1)
y = ssd['yield strength']

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test, y_train , y_test = train_test_split(X,y,test_size= 1/3,random_state=100)

# %%
X_train

# %%
y_train

# %% [markdown]
# ## Create Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

# %%
y_pred

# %%
y_test

# %% [markdown]
# # Calculate performance of Test Set

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
ssd['yield strength'].mean()

# %%
MAE = mean_absolute_error(y_test,y_pred)
MAE

# %%
MSE = mean_squared_error(y_test,y_pred)
MSE

# %%
RMSE = np.sqrt(MSE)
RMSE

# %%
sns.histplot(data=ssd,x='yield strength')
plt.savefig('YS_Barplt.png')

# %% [markdown]
# ## Retraining Model on Full Data

# %%
final_model = LinearRegression()

# %%
final_model.fit(X,y)

# %%
y_hat = final_model.predict(X)

# %%
fig, axes = plt.subplots(nrows=4,ncols=4, figsize=(16,6))

axes[0,0].plot(ssd['fe'],ssd['yield strength'],'o' )
axes[0,0].plot(ssd['fe'],y_hat,'o' , color='red')
axes[0,0].set_title('yield strength vs fe')

axes[0,1].plot(ssd['c'],ssd['yield strength'],'o')
axes[0,1].plot(ssd['c'],y_hat,'o', color='red')
axes[0,1].set_title('yield strength vs c')

axes[0,2].plot(ssd['mn'],ssd['yield strength'],'o')
axes[0,2].plot(ssd['mn'],y_hat,'o', color='red')
axes[0,2].set_title('yield strength vs mn')

axes[0,3].plot(ssd['si'],ssd['yield strength'],'o')
axes[0,3].plot(ssd['si'],y_hat,'o', color='red')
axes[0,3].set_title('yield strength vs si')

axes[1,0].plot(ssd['cr'],ssd['yield strength'],'o')
axes[1,0].plot(ssd['cr'],y_hat,'o', color='red')
axes[1,0].set_title('yield strength vs cr')

axes[1,1].plot(ssd['ni'],ssd['yield strength'],'o')
axes[1,1].plot(ssd['ni'],y_hat,'o', color='red')
axes[1,1].set_title('yield strength vs ni')

axes[1,2].plot(ssd['mo'],ssd['yield strength'],'o')
axes[1,2].plot(ssd['mo'],y_hat,'o', color='red')
axes[1,2].set_title('yield strength vs mo')

axes[1,3].plot(ssd['v'],ssd['yield strength'],'o')
axes[1,3].plot(ssd['v'],y_hat,'o', color='red')
axes[1,3].set_title('yield strength vs v')

axes[2,0].plot(ssd['n'],ssd['yield strength'],'o')
axes[2,0].plot(ssd['n'],y_hat,'o', color='red')
axes[2,0].set_title('yield strength vs n')

axes[2,1].plot(ssd['nb'],ssd['yield strength'],'o')
axes[2,1].plot(ssd['nb'],y_hat,'o', color='red')
axes[2,1].set_title('yield strength vs nb')

axes[2,2].plot(ssd['co'],ssd['yield strength'],'o')
axes[2,2].plot(ssd['co'],y_hat,'o', color='red')
axes[2,2].set_title('yield strength vs co')

axes[2,3].plot(ssd['w'],ssd['yield strength'],'o')
axes[2,3].plot(ssd['w'],y_hat,'o', color='red')
axes[2,3].set_title('yield strength vs w')

axes[3,0].plot(ssd['al'],ssd['yield strength'],'o')
axes[3,0].plot(ssd['al'],y_hat,'o', color='red')
axes[3,0].set_title('yield strength vs al')

axes[3,1].plot(ssd['ti'],ssd['yield strength'],'o')
axes[3,1].plot(ssd['ti'],y_hat,'o', color='red')
axes[3,1].set_title('yield strength variations')
plt.savefig('yield_strength_variations.png')

# %%
res = y_hat-y

# %%
sns.scatterplot(x=y,y=res)
plt.axhline(y=0, c='r')
plt.savefig('YS_Scatterplt.png')

# %% [markdown]
# ## Coefficients

# %%
final_model.coef_

# %%
ssd.head()

# %%
ssd.corr()

# %% [markdown]
# ## Precting new yield strength

# %%
new_yield_strength = [[37.625,0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]]

# %%
final_model.predict(new_yield_strength)

# %% [markdown]
# ## Now modeling and predicting tensile strength

# %%
y = ssd['tensile strength']

# %%
X_train

# %%
y_train

# %%
ssd['tensile strength'].mean()

# %%
MAE = mean_absolute_error(y_test,y_pred)
MAE

# %%
MSE = mean_squared_error(y_test,y_pred)
MSE

# %%
RMSE = np.sqrt(MSE)
RMSE

# %%
sns.histplot(data=ssd,x='tensile strength')
plt.savefig('TS_plt.png')

# %%
final_model = LinearRegression()

# %%
final_model.fit(X,y)

# %%
y_hat = final_model.predict(X)

# %%
fig, axes = plt.subplots(nrows=4,ncols=4, figsize=(16,6))

axes[0,0].plot(ssd['fe'],ssd['tensile strength'],'o' )
axes[0,0].plot(ssd['fe'],y_hat,'o' , color='red')
axes[0,0].set_title('tensile strength vs fe')

axes[0,1].plot(ssd['c'],ssd['tensile strength'],'o')
axes[0,1].plot(ssd['c'],y_hat,'o', color='red')
axes[0,1].set_title('tensile sterngth vs c')

axes[0,2].plot(ssd['mn'],ssd['tensile strength'],'o')
axes[0,2].plot(ssd['mn'],y_hat,'o', color='red')
axes[0,2].set_title('tensile strength vs mn')

axes[0,3].plot(ssd['si'],ssd['tensile strength'],'o')
axes[0,3].plot(ssd['si'],y_hat,'o', color='red')
axes[0,3].set_title('tensile strength vs si')

axes[1,0].plot(ssd['cr'],ssd['tensile strength'],'o')
axes[1,0].plot(ssd['cr'],y_hat,'o', color='red')
axes[1,0].set_title('tensile strength vs cr')

axes[1,1].plot(ssd['ni'],ssd['tensile strength'],'o')
axes[1,1].plot(ssd['ni'],y_hat,'o', color='red')
axes[1,1].set_title('tensile strength vs ni')

axes[1,2].plot(ssd['mo'],ssd['tensile strength'],'o')
axes[1,2].plot(ssd['mo'],y_hat,'o', color='red')
axes[1,2].set_title('tensile strength vs mo')

axes[1,3].plot(ssd['v'],ssd['tensile strength'],'o')
axes[1,3].plot(ssd['v'],y_hat,'o', color='red')
axes[1,3].set_title('tensile strength vs v')

axes[2,0].plot(ssd['n'],ssd['tensile strength'],'o')
axes[2,0].plot(ssd['n'],y_hat,'o', color='red')
axes[2,0].set_title('tensile strength vs n')

axes[2,1].plot(ssd['nb'],ssd['tensile strength'],'o')
axes[2,1].plot(ssd['nb'],y_hat,'o', color='red')
axes[2,1].set_title('tensile strength vs nb')

axes[2,2].plot(ssd['co'],ssd['tensile strength'],'o')
axes[2,2].plot(ssd['co'],y_hat,'o', color='red')
axes[2,2].set_title('tensile strength vs co')

axes[2,3].plot(ssd['w'],ssd['tensile strength'],'o')
axes[2,3].plot(ssd['w'],y_hat,'o', color='red')
axes[2,3].set_title('tensile strength vs w')

axes[3,0].plot(ssd['al'],ssd['tensile strength'],'o')
axes[3,0].plot(ssd['al'],y_hat,'o', color='red')
axes[3,0].set_title('tensile strength vs al')

axes[3,1].plot(ssd['ti'],ssd['tensile strength'],'o')
axes[3,1].plot(ssd['ti'],y_hat,'o', color='red')
axes[3,1].set_title('tensile strength vs ti')
plt.savefig('TS_plot.png')

# %%
res = y_hat-y

# %%
sns.scatterplot(x=y,y=res)
plt.axhline(y=0, c='r')
plt.savefig('TS_plt.png')

# %%
final_model.coef_

# %%
ssd.head()

# %%
ssd.corr()

# %%
new_tensile_strength = [[37.625,0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]]

# %% [markdown]
# ## Precting new tensile strength

# %%
final_model.predict(new_tensile_strength)

# %% [markdown]
# ## Now modeling and predicting elongation

# %%
y = ssd['elongation']

# %%
X_train

# %%
y_train

# %%
ssd['elongation'].mean()

# %%
MAE = mean_absolute_error(y_test,y_pred)
MAE

# %%
MSE = mean_squared_error(y_test,y_pred)
MSE

# %%
RMSE = np.sqrt(MSE)
RMSE

# %%
sns.histplot(data=ssd,x='elongation')
plt.savefig('ELN_plt.png')

# %%
final_model = LinearRegression()

# %%
final_model.fit(X,y)

# %%
y_hat = final_model.predict(X)

# %%
fig, axes = plt.subplots(nrows=4,ncols=4, figsize=(16,6))

axes[0,0].plot(ssd['fe'],ssd['elongation'],'o' )
axes[0,0].plot(ssd['fe'],y_hat,'o' , color='red')
axes[0,0].set_title('elongation vs fe')

axes[0,1].plot(ssd['c'],ssd['elongation'],'o')
axes[0,1].plot(ssd['c'],y_hat,'o', color='red')
axes[0,1].set_title('elongation vs c')

axes[0,2].plot(ssd['mn'],ssd['elongation'],'o')
axes[0,2].plot(ssd['mn'],y_hat,'o', color='red')
axes[0,2].set_title('elongation vs mn')

axes[0,3].plot(ssd['si'],ssd['elongation'],'o')
axes[0,3].plot(ssd['si'],y_hat,'o', color='red')
axes[0,3].set_title('elongation vs si')

axes[1,0].plot(ssd['cr'],ssd['elongation'],'o')
axes[1,0].plot(ssd['cr'],y_hat,'o', color='red')
axes[1,0].set_title('elongation vs cr')

axes[1,1].plot(ssd['ni'],ssd['elongation'],'o')
axes[1,1].plot(ssd['ni'],y_hat,'o', color='red')
axes[1,1].set_title('elongation vs ni')

axes[1,2].plot(ssd['mo'],ssd['elongation'],'o')
axes[1,2].plot(ssd['mo'],y_hat,'o', color='red')
axes[1,2].set_title('elongation vs mo')

axes[1,3].plot(ssd['v'],ssd['elongation'],'o')
axes[1,3].plot(ssd['v'],y_hat,'o', color='red')
axes[1,3].set_title('elongation vs v')

axes[2,0].plot(ssd['n'],ssd['elongation'],'o')
axes[2,0].plot(ssd['n'],y_hat,'o', color='red')
axes[2,0].set_title('elongation vs n')

axes[2,1].plot(ssd['nb'],ssd['elongation'],'o')
axes[2,1].plot(ssd['nb'],y_hat,'o', color='red')
axes[2,1].set_title('elongation vs nb')

axes[2,2].plot(ssd['co'],ssd['elongation'],'o')
axes[2,2].plot(ssd['co'],y_hat,'o', color='red')
axes[2,2].set_title('elongation vs co')

axes[2,3].plot(ssd['w'],ssd['tensile strength'],'o')
axes[2,3].plot(ssd['w'],y_hat,'o', color='red')
axes[2,3].set_title('tensile strength vs w')

axes[3,0].plot(ssd['al'],ssd['elongation'],'o')
axes[3,0].plot(ssd['al'],y_hat,'o', color='red')
axes[3,0].set_title('elongation vs al')

axes[3,1].plot(ssd['ti'],ssd['elongation'],'o')
axes[3,1].plot(ssd['ti'],y_hat,'o', color='red')
axes[3,1].set_title('elongation vs ti')
plt.savefig('elonation_plt.png')

# %%
res = y_hat-y

# %%
sns.scatterplot(x=y,y=res)
plt.axhline(y=0, c='r')
plt.savefig('elongation_scatter_plt.png')

# %%
final_model.coef_

# %%
ssd.head()

# %%
ssd.corr()

# %% [markdown]
# ## Predicting new Elongation

# %%
new_elongation = [[37.625,0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]]

# %%
final_model.predict(new_elongation)

# %% [markdown]
# ## Implementing The Linear Regression Model With Cleaning of the respective target variable columns

# %%
#cleaned = smogn.smoter(data=ss,y="yield strength")

# %%
# !pip list

# %%
#ss

# %%
#X=ss[['c','mn','si','cr','ni','mo','v','n','nb','co','w','al','ti']]
#y=ss['yield strength']

# %%
#regr = linear_model.LinearRegression()
#regr.fit(X, y)

# %%
#try:
    #cleaned = smogn.smoter(data=ss, y="tensile strength")
    #print(cleaned.head())
#except ValueError as ve:
    #print(f"ValueError: {ve}")
     # Additional error handling or debugging steps

# %%
#X1=ss[['c','mn','si','cr','ni','mo','v','n','nb','co','w','al','ti']]
#y1=ss['tensile strength']

# %%
#regr1 = linear_model.LinearRegression()
#regr1.fit(X1, y1)

# %%
#cleaned = smogn.smoter(data=ss,y="elongation")

# %%
#X2=ss[['c','mn','si','cr','ni','mo','v','n','nb','co','w','al','ti']]
#y2=ss['elongation']

# %%
#regr2 = linear_model.LinearRegression()
#regr2.fit(X2, y2)

# %%
#predictedyieldstrength = regr.predict([[0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]])
#print(regr.coef_)
#print(predictedyieldstrength)

# %%
#predictedtensilestrength = regr1.predict([[0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]])
#print(regr1.coef_)
#print(predictedtensilestrength)

# %%
#predictedelongation = regr2.predict([[0.025,1,0.5,12.75,36,8,0,0,0,0,0,1.15,2.95]])
#print(regr2.coef_)
#print(predictedelongation )
